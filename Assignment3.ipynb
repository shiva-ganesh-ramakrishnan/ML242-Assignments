# %% [markdown]
# <h1 align="center"> CSE 242 Assignment 3, Spring 2024
#
# **<h1> Name: Shiva Ganesh Ramakrishnan**
#
# <h2> 4 Questions, 100 pts, due: 23:59 pm, May 6th, 2024

# %% [markdown]
# ## Instruction
#
# - Submit your assignments onto **Gradescope** by the due date. Upload a <code>zip</code> file containing:
#
#     (1) The saved/latest <code>.ipynb</code> file, please **rename this file with your name included**.
#
#     (2) Also save your file into a pdf version, if error appears, save an html version instead (easy to grade for written questions).
#
#     (3) All other materials to make your <code>.ipynb</code> file runnable.
#
#     **For assignment related questions, please reach TA or grader through Slack/Email.**
#
# - This is an **individual** assignment. All help from others (from the web, books other than text, or people other than the TA or instructor) must be clearly acknowledged.
#
# ## Objective
#
# - **Task 1:** Perceptron (math)
# - **Task 2:** Support Vector Machine (math)
# - **Task 3:** Image Classification (with Scikit-learn)
# - **Task 4:** Coding Linear Regression from scratch

# %% [markdown]
# # Question 1. (Perceptron, 30 pts)

# %% [markdown]
# ## (a -- 10 pts)
#
# On what kinds of training data does the perceptron algorithm converge?
#
# **Answer:**
# If we are talking only about basic perceptron, we can only train it with Linearly separable, classification data which has only two classes (binary).
#
# We also have to make sure data is shuffled properly

# %% [markdown]
# ## (b -- 5*4 pts)
#
# Simulate one pass through the following data with the perceptron algorithm described in lecture and homework.
# Use the learning rate $\eta = 1$.
#
# Start with $w=(0,0,0)$ and show the resulting weight vector after each example.
#
# (Assume that the perceptron algorithm predicts incorrectly when $w \cdot x = 0$, and ignore the bias term.)
#
# | $x_1$  | $x_2$ | $x_3$ |   $y$ |
# | :--- | :--- | :--- | :--- |
# | 1 | 0 | 1 |  +1|
# | 0 | -1 | 1 |  -1|
# | 1 | 1 | 1 | +1|
# | -1 | 2 | 0 |  -1|
#
# Initially, $w = ( 0, 0, 0)$.
#
# After the first example, $w = ( 1, 0, 1 )$;
#
# After the second example, $w = ( 1, 1, 0 )$;
#
# After the third example, $w = ( 1, 1, 0 )$;
#
# After the fourth example, $w = ( 2, -1, 0 )$.
#
# **Reminder:** if you are unsure about your answers, give as many details as possible so that you won't get 0 points in the wrong answers. If you want, you can attach an image of your work.

# %% [markdown]
# # Question 2. (Support Vector Machines, 30 pts)
# Suppose that we have the following training set (where the instances have two features):
#
# | $x_1$ | $x_2$ | $y$ |
# | :--- | :--- | :--- |
# | 1 | 1  |  +1|
# | 1 | 2  |  +1|
# | 2 | 1  |  +1|
# | 0 | 0  |  -1|
# | 1 | 0  |  -1|
# | 0 | 1  |  -1|
#
# ## (a -- 10 pts)
#
# Plot them (by hand or with python) and find the support vectors (by eye).

# %%
import matplotlib.pyplot as plt

x_1 = [1, 1, 2, 0, 1, 0]
x_2 = [1, 2, 1, 0, 0, 1]

y = [1, 1, 1, -1, -1, -1]

plt.scatter(x_1, x_2, c=y)

print("Support vectors are : [1,0],[0,1],[1,1]")
# Out:
# Support vectors are : [1,0],[0,1],[1,1]

# %% [markdown]
# ## (b -- 10 + 10 pts)
#
# Using the support vectors, find the equation for the maximum margin separating plane, and determine the geometric margin. (Assume a simple linear SVM and no soft-margin).

# %%
from IPython.display import Image, display
# Replace the figure name
img1 = Image(filename='/content/ML_Assn3_2b1.JPG')
img2 = Image(filename='/content/ML_Assn3_2b2.JPG')
display(img1, img2)

# %% [markdown]
# # Question 3. (Binary Image Classification, 30 pts + bonus pts)
#
# In this question, you will perform a binary image classification task with scikit-learn implemented models. Your will see the importance of a powerful feature extractor. Meanwhile, you will learn to perform hyper-parameter tuning and select machine learning models with scikit-learn. Please **do not** use deep learning models for training use in this question.

# %% [markdown]
# #### Import/Install required packages

# %%
# Import libraries
import os
from os.path import join
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
from PIL import Image
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %% [markdown]
# #### Data preprocessing

# %%
#Added to unzip the images
# !unzip -o "/content/cat_vs_dog.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: cat_vs_dog/train/dogs/dog.1109.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1109.jpg
#   inflating: cat_vs_dog/train/dogs/dog.649.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.649.jpg
#   inflating: cat_vs_dog/train/dogs/dog.891.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.891.jpg
#   inflating: cat_vs_dog/train/dogs/dog.2.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.2.jpg
#   inflating: cat_vs_dog/train/dogs/dog.42.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.42.jpg
#   inflating: cat_vs_dog/train/dogs/dog.56.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.56.jpg
#   inflating: cat_vs_dog/train/dogs/dog.885.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.885.jpg
#   inflating: cat_vs_dog/train/dogs/dog.81.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.81.jpg
#   inflating: cat_vs_dog/train/dogs/dog.852.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.852.jpg
#   inflating: cat_vs_dog/train/dogs/dog.846.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.846.jpg
#   inflating: cat_vs_dog/train/dogs/dog.95.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.95.jpg
#   inflating: cat_vs_dog/train/dogs/dog.94.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.94.jpg
#   inflating: cat_vs_dog/train/dogs/dog.847.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.847.jpg
#   inflating: cat_vs_dog/train/dogs/dog.853.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.853.jpg
#   inflating: cat_vs_dog/train/dogs/dog.80.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.80.jpg
#   inflating: cat_vs_dog/train/dogs/dog.884.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.884.jpg
#   inflating: cat_vs_dog/train/dogs/dog.57.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.57.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1108.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1108.jpg
#   inflating: cat_vs_dog/train/dogs/dog.43.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.43.jpg
#   inflating: cat_vs_dog/train/dogs/dog.3.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.3.jpg
#   inflating: cat_vs_dog/train/dogs/dog.890.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.890.jpg
#   inflating: cat_vs_dog/train/dogs/dog.648.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.648.jpg
#   inflating: cat_vs_dog/train/dogs/dog.660.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.660.jpg
#   inflating: cat_vs_dog/train/dogs/dog.106.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.106.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1120.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1120.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1134.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1134.jpg
#   inflating: cat_vs_dog/train/dogs/dog.112.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.112.jpg
#   inflating: cat_vs_dog/train/dogs/dog.674.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.674.jpg
#   inflating: cat_vs_dog/train/dogs/dog.489.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.489.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1487.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1487.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1493.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1493.jpg
#   inflating: cat_vs_dog/train/dogs/dog.338.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.338.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1478.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1478.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1322.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1322.jpg
#   inflating: cat_vs_dog/train/dogs/dog.304.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.304.jpg
#   inflating: cat_vs_dog/train/dogs/dog.462.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.462.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1444.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1444.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1450.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1450.jpg
#   inflating: cat_vs_dog/train/dogs/dog.476.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.476.jpg
#   inflating: cat_vs_dog/train/dogs/dog.310.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.310.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1336.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1336.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1295.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1295.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1281.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1281.jpg
#   inflating: cat_vs_dog/train/dogs/dog.258.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.258.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1256.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1256.jpg
#   inflating: cat_vs_dog/train/dogs/dog.270.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.270.jpg
#   inflating: cat_vs_dog/train/dogs/dog.516.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog
jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.303.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1325.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1325.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1443.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1443.jpg
#   inflating: cat_vs_dog/train/dogs/dog.465.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.465.jpg
#   inflating: cat_vs_dog/train/dogs/dog.471.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.471.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1457.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1457.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1331.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1331.jpg
#   inflating: cat_vs_dog/train/dogs/dog.317.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.317.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1480.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1480.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1494.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1494.jpg
#   inflating: cat_vs_dog/train/dogs/dog.50.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.50.jpg
#   inflating: cat_vs_dog/train/dogs/dog.883.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.883.jpg
#   inflating: cat_vs_dog/train/dogs/dog.129.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.129.jpg
#   inflating: cat_vs_dog/train/dogs/dog.897.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.897.jpg
#   inflating: cat_vs_dog/train/dogs/dog.44.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.44.jpg
#   inflating: cat_vs_dog/train/dogs/dog.4.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.4.jpg
#   inflating: cat_vs_dog/train/dogs/dog.667.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.667.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1127.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1127.jpg
#   inflating: cat_vs_dog/train/dogs/dog.101.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.101.jpg
#   inflating: cat_vs_dog/train/dogs/dog.115.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.115.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1133.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1133.jpg
#   inflating: cat_vs_dog/train/dogs/dog.78.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.78.jpg
#   inflating: cat_vs_dog/train/dogs/dog.673.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.673.jpg
#   inflating: cat_vs_dog/train/dogs/dog.840.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.840.jpg
#   inflating: cat_vs_dog/train/dogs/dog.698.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.698.jpg
#   inflating: cat_vs_dog/train/dogs/dog.93.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.93.jpg
#   inflating: cat_vs_dog/train/dogs/dog.87.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.87.jpg
#   inflating: cat_vs_dog/train/dogs/dog.854.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.854.jpg
#   inflating: cat_vs_dog/train/dogs/dog.868.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.868.jpg
#   inflating: cat_vs_dog/train/dogs/dog.869.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.869.jpg
#   inflating: cat_vs_dog/train/dogs/dog.855.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.855.jpg
#   inflating: cat_vs_dog/train/dogs/dog.86.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.86.jpg
#   inflating: cat_vs_dog/train/dogs/dog.92.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.92.jpg
#   inflating: cat_vs_dog/train/dogs/dog.699.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.699.jpg
#   inflating: cat_vs_dog/train/dogs/dog.841.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.841.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1132.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1132.jpg
#   inflating: cat_vs_dog/train/dogs/dog.114.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.114.jpg
#   inflating: cat_vs_dog/train/dogs/dog.672.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.672.jpg
#   inflating: cat_vs_dog/train/dogs/dog.79.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.79.jpg
#   inflating: cat_vs_dog/train/dogs/dog.666.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.666.jpg
#   inflating: cat_vs_dog/train/dogs/dog.100.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.100.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1126.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1126.jpg
#   inflating: cat_vs_dog/train/dogs/dog.128.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.128.jpg
#   inflating: cat_vs_dog/train/dogs/dog.5.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.5.jpg
#   inflating: cat_vs_dog/train/dogs/dog.45.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.45.jpg
#   inflating: cat_vs_dog/train/dogs/dog.896.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.896.jpg
#   inflating: cat_vs_dog/train/dogs/dog.882.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.882.jpg
#   inflating: cat_vs_dog/train/dogs/dog.51.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.51.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1495.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1495.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1481.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1481.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1456.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1456.jpg
#   inflating: cat_vs_dog/train/dogs/dog.470.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.470.jpg
#   inflating: cat_vs_dog/train/dogs/dog.316.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.316.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1330.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1330.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1324.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1324.jpg
#   inflating: cat_vs_dog/train/dogs/dog.302.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.302.jpg
#   inflating: cat_vs_dog/train/dogs/dog.464.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.464.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1442.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1442.jpg
#   inflating: cat_vs_dog/train/dogs/dog.1318.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog.1318.jpg
#   inflating: cat_vs_dog/train/dogs/dog.458.jpg
#   inflating: __MACOSX/cat_vs_dog/train/dogs/._dog
jpg
#   inflating: __MACOSX/cat_vs_dog/train/cats/._cat.208.jpg
#   inflating: cat_vs_dog/train/cats/cat.546.jpg
#   inflating: __MACOSX/cat_vs_dog/train/cats/._cat.546.jpg
#   inflating: cat_vs_dog/train/cats/cat.220.jpg
#   inflating: __MACOSX/cat_vs_dog/train/cats/._cat.220.jpg
#   inflating: cat_vs_dog/train/cats/cat.234.jpg
#   inflating: __MACOSX/cat_vs_dog/train/cats/._cat.234.jpg
#   inflating: cat_vs_dog/train/cats/cat.552.jpg
#   inflating: __MACOSX/cat_vs_dog/train/cats/._cat.552.jpg
#   inflating: cat_vs_dog/train/cats/cat.1022.jpg
#   inflating: __MACOSX/cat_vs_dog/train/cats/._cat.1022.jpg
#   inflating: cat_vs_dog/train/cats/cat.1036.jpg
#   inflating: __MACOSX/cat_vs_dog/train/cats/._cat.1036.jpg
#   inflating: cat_vs_dog/train/cats/cat.585.jpg
#   inflating: __MACOSX/cat_vs_dog/train/cats/._cat.585.jpg
#   inflating: cat_vs_dog/train/cats/cat.591.jpg
#   inflating: __MACOSX/cat_vs_dog/train/cats/._cat.591.jpg
#   inflating: cat_vs_dog/train/cats/cat.778.jpg
#   inflating: __MACOSX/cat_vs_dog/train/cats/._cat.778.jpg
#   inflating: cat_vs_dog/train/cats/cat.744.jpg
#   inflating: __MACOSX/cat_vs_dog/train/cats/._cat.744.jpg
#   inflating: cat_vs_dog/train/cats/cat.988.jpg
#   inflating: __MACOSX/cat_vs_dog/train/cats/._cat.988.jpg
#   inflating: cat_vs_dog/train/cats/cat.750.jpg
#   inflating: __MACOSX/cat_vs_dog/train/cats/._cat.750.jpg
#   inflating: cat_vs_dog/train/cats/cat.1220.jpg
#   inflating: __MACOSX/cat_vs_dog/train/cats/._cat.1220.jpg
#   inflating: cat_vs_dog/train/cats/cat.963.jpg
#   inflating: __MACOSX/cat_vs_dog/train/cats/._cat.963.jpg
#   inflating: cat_vs_dog/train/cats/cat.977.jpg
#   inflating: __MACOSX/cat_vs_dog/train/cats/._cat.977.jpg
#   inflating: cat_vs_dog/train/cats/cat.1234.jpg
#   inflating: __MACOSX/cat_vs_dog/train/cats/._cat.1234.jpg
#   inflating: cat_vs_dog/train/cats/cat.787.jpg
#   inflating: __MACOSX/cat_vs_dog/train/cats/._cat.787.jpg
#   inflating: cat_vs_dog/train/cats/cat.793.jpg
#   inflating: __MACOSX/cat_vs_dog/train/cats/._cat.793.jpg
#   inflating: cat_vs_dog/train/cats/cat.1208.jpg
#   inflating: __MACOSX/cat_vs_dog/train/cats/._cat.1208.jpg

# %%
# A help function which appends the path list for train and test image folder
def get_path(is_train=True):
    if is_train:
        directory = "train"
    else:
        directory = "test"

    # Append the image path to a list for imgaes that contain a dog
    dog_image_dir = f'/content/cat_vs_dog/{directory}/dogs'
    dog_paths = [join(dog_image_dir,filename) for filename in os.listdir(dog_image_dir) if filename.endswith('.jpg')]

    # Append the image path to a list for imgaes that contain a cat
    cat_image_dir = f'/content/cat_vs_dog/{directory}/cats'
    cat_paths = [join(cat_image_dir, filename) for filename in os.listdir(cat_image_dir) if filename.endswith('.jpg')]

    img_paths = dog_paths + cat_paths

    # Return the unshuffled image paths
    return img_paths

# %%
# Show how many figures contained in the train and test dataset
print(f"There are {len(get_path())} train images and {len(get_path(is_train=False))} test images.")
# Out:
# There are 3002 train images and 1000 test images.

# %% [markdown]
# Take a look at a few randomly selected example images we will deal with.

# %%
import random

fig,ax = plt.subplots(2,5)
index_list = [random.randrange(1, len(get_path()), 1) for i in range(10)]
print(index_list)
train_paths = get_path()

filenames=[train_paths[idx] for idx in index_list]
for i in range(10):
    with open(filenames[i],'rb') as f:
        image=Image.open(f)
        ax[i%2][i//2].imshow(image)
        ax[i%2][i//2].axis('off')
fig.show()
# Out:
# [280, 1772, 1622, 1477, 2755, 793, 2602, 1310, 244, 784]

# %% [markdown]
# #### Clearly, the above images are of different shape/size.

# %%
# See the shape of an image
sample_img = Image.open(train_paths[1])
print(np.array(sample_img).shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# #### Standard PCA methods implemented in Scikit-learn do not work for color imgaes (RGB), so we will transform the images into grayscale.

# %%
import matplotlib

# Transform color images to grayscale
def rgb2gray(rgb_img):
    return np.dot(rgb_img[...,:3], [0.2989, 0.5870, 0.1140])

# Given the image path, return the resized image as an numpy 2d array
def get_image(path):
    img = Image.open(path)
    img = img.resize((200,200))
    img.save(path)
    img = matplotlib.image.imread(path)
    gray = rgb2gray(img)
    return np.array(gray)

# %%
print(get_image(train_paths[1]).shape)
# Out:
# (200, 200)

# %% [markdown]
# #### Append image data and labels in to list

# %%
# Prepare the raw data: grayscale, train images and train labels
h, w = get_image(train_paths[1]).shape
train_data = np.empty((len(train_paths), h, w))
train_label = [1] * np.int64(len(train_paths)/2) + [0] * np.int64(len(train_paths)/2)
count = -1
for pth in train_paths:
    count += 1
    image = get_image(pth)
    train_data[count] = image
n_samples = train_data.shape[0]
X = np.empty((n_samples, h * w))
for i in range(n_samples):
    X[i] = train_data[i].flatten()
y = train_label
print(f"The shape of the training data is {X.shape}")
# Out:
# The shape of the training data is (3002, 40000)

# %% [markdown]
# #### Prepare the raw test data

# %%
test_paths = get_path(is_train=False)


# Prepare the raw dataframe: grayscale, test images and test labels
test_data = np.empty((len(test_paths), h, w))
test_label = [1] * np.int64(len(test_paths)/2) + [0] * np.int64(len(test_paths)/2)
count = -1
for pth in test_paths:
    count += 1
    image = get_image(pth)
    test_data[count] = image
n_samples = test_data.shape[0]
X_test = np.empty((n_samples, h * w))
for i in range(n_samples):
    X_test[i] = test_data[i].flatten()
y_test = test_label
print(f"The shape of the test data is {X_test.shape}")
# Out:
# The shape of the test data is (1000, 40000)

# %% [markdown]
# #### Shuffle the training dataset

# %%
# Shuffle the training dataset
from sklearn.utils import shuffle
X_train, y_train = shuffle(X, y, random_state=0)
X_train
print(f"The shape of the training data is {X.shape}")
# Out:
# The shape of the training data is (3002, 40000)

# %%
# Import additional libaries
from sklearn.decomposition import PCA
from sklearn.svm import SVC

# %% [markdown]
# ##Question 3.1 Reducing the dimensions (feature extraction using PCA)

# %% [markdown]
# Directly training on current training dataset may consume a large amount of time. One wise choice is to firstly perform feature extraction so that we do not have to train model with unnecessary features.

# %% [markdown]
# ### 3.1.1 SVM on extracted features (15pts)

# %%
# The list of number of components for PCA
n_list = [10, 20, 50, 100, 150, 200, 498]
for i in range(len(n_list)):
    n_components = n_list[i]
    print(f"############ Number of components is {n_components} ############")

    #
    # your code here for PCA
    #

    pca = PCA(n_components=n_components)
    pca.fit(X_train)
    print("Projecting the input data on the eigenimages orthonormal basis")
    X_train_pca = pca.transform(X_train)
    print(X_train_pca.shape)
    X_test_pca = pca.transform(X_test)

    #
    # your code here for training SVM classifier and prediction on X_test (y_pred are predicted labels in line below)
    #
    classifier = SVC()
    classifier.fit(X_train_pca, y_train)

    y_pred = classifier.predict(X_test_pca)

    print(f"Confusion matrix: {confusion_matrix(y_test, y_pred, labels=range(2))}")

    print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
# Out:
# ############ Number of components is 10 ############
# Projecting the input data on the eigenimages orthonormal basis
# (3002, 10)
# Confusion matrix: [[282 218]
#  [173 327]]
# Accuracy: 0.609
# ############ Number of components is 20 ############
# Projecting the input data on the eigenimages orthonormal basis
# (3002, 20)
# Confusion matrix: [[290 210]
#  [162 338]]
# Accuracy: 0.628
# ############ Number of components is 50 ############
# Projecting the input data on the eigenimages orthonormal basis
# (3002, 50)
# Confusion matrix: [[292 208]
#  [167 333]]
# Accuracy: 0.625
# ############ Number of components is 100 ############
# Projecting the input data on the eigenimages orthonormal basis
# (3002, 100)
# Confusion matrix: [[291 209]
#  [170 330]]
# Accuracy: 0.621
# ############ Number of components is 150 ############
# Projecting the input data on the eigenimages orthonormal basis
# (3002, 150)
# Confusion matrix: [[292 208]
#  [166 334]]
# Accuracy: 0.626
# ############ Number of components is 200 ############
# Projecting the input data on the eigenimages orthonormal basis
# (3002, 200)
# Confusion matrix: [[288 212]
#  [165 335]]
# Accuracy: 0.623
# ############ Number of components is 498 ############
# Projecting the input data on the eigenimages orthonormal basis
# (3002, 498)
# Confusion matrix: [[290 210]
#  [170 330]]
# Accuracy: 0.62

# %% [markdown]
# ### 3.1.2 Logistic regression on extracted features (15pts)

# %%
from sklearn.linear_model import LogisticRegression
# The list of number of components for PCA
n_list = [10, 20, 50, 100, 150, 200, 498]
for i in range(len(n_list)):
    n_components = n_list[i]
    print(f"############ Number of components is {n_components} ############")

    #
    # your code here for PCA
    #

    pca = PCA(n_components=n_components)
    pca.fit(X_train)

    print("Projecting the input data on the eigenimages orthonormal basis")
    X_train_pca = pca.transform(X_train)
    print(X_train_pca.shape)
    X_test_pca = pca.transform(X_test)

    #
    # your code here for training Logistic Regression classifier and prediction on X_test (y_pred are predicted labels in line below)
    #
    clf = LogisticRegression(random_state=0).fit(X_train_pca, y_train)
    y_pred = clf.predict(X_test_pca)

    print(f"Confusin matrix: {confusion_matrix(y_test, y_pred, labels=range(2))}")

    print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
# Out:
# ############ Number of components is 10 ############
# Projecting the input data on the eigenimages orthonormal basis
# (3002, 10)
# Confusin matrix: [[277 223]
#  [226 274]]
# Accuracy: 0.551
# ############ Number of components is 20 ############
# Projecting the input data on the eigenimages orthonormal basis
# (3002, 20)
# Confusin matrix: [[279 221]
#  [213 287]]
# Accuracy: 0.566
# ############ Number of components is 50 ############
# Projecting the input data on the eigenimages orthonormal basis
# (3002, 50)
# Confusin matrix: [[272 228]
#  [231 269]]
# Accuracy: 0.541
# ############ Number of components is 100 ############
# Projecting the input data on the eigenimages orthonormal basis
# (3002, 100)
# Confusin matrix: [[273 227]
#  [229 271]]
# Accuracy: 0.544
# ############ Number of components is 150 ############
# Projecting the input data on the eigenimages orthonormal basis
# (3002, 150)
# Confusin matrix: [[276 224]
#  [229 271]]
# Accuracy: 0.547
# ############ Number of components is 200 ############
# Projecting the input data on the eigenimages orthonormal basis
# (3002, 200)
# Confusin matrix: [[266 234]
#  [228 272]]
# Accuracy: 0.538
# ############ Number of components is 498 ############
# Projecting the input data on the eigenimages orthonormal basis
# (3002, 498)
# Confusin matrix: [[255 245]
#  [236 264]]
# Accuracy: 0.519

# %% [markdown]
# **Leaderboard Depending on your best achieved accuracy score, the remaining points and bonus points are organized as below:**
#
# Accuracy score > 55%: 30 pts
#
# Accuracy score 50-55%: 15 pts
#
# Accuracy score < 50%: 5 pts

# %% [markdown]
# # Question 4. (Coding assignment: Linear Regression, 10 pts)

# %% [markdown]
# In this question, you'll be coding up linear regression algorithm from scratch.
#
# ### Instructions
# - Download the datasets `heights_weights.csv`. **Place these files in the same directory as this notebook.**
# - You are **NOT** allowed to use machine learning libraries such as `scikit-learn` to build the models for this question.
# - You are required to complete the functions defined in the code blocks following each question. Fill out sections of the code marked `"YOUR CODE HERE"`.
# - You're free to add any number of methods within each class.
# - You may also add any number of additional code blocks that you deem necessary.
# - If not comfortable with Python, you can code in Matlab. Make sure to add the files in the submission zip folder.
# -  You may use `scikit-learn` package **only** to compare your final error.

# %%
# Importing Libraries
import time
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Data Preparation.
# To keep things simple, first we'll use a toy dataset to test our implementation. This dataset contains the heights and weights of a few individuals. Our goal is to predict the weight of an individual given their height using a linear regression model.

# %%
df = pd.read_csv('./heights_weights.csv')

# %%
df.head()
# Out:
#    Height  Weight
# 0    1.47   52.21
# 1    1.50   53.12
# 2    1.52   54.48
# 3    1.55   55.84
# 4    1.57   57.20

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Height'], df['Weight'], marker='X')
plt.xlabel("Height")
plt.ylabel("Weight")
plt.show()

# %% [markdown]
# Looking at the distribution of the data, it seems like `Weight` and `Height` have a linear relationship. Hence, a linear regression model should be able to capture this relationship.
#
# Let's us convert the dataframe `df` to a Numpy array so that it is easier to perform operations on it.

# %%
X_train = np.array(df['Height'])
y_train = np.array(df['Weight'])
X_train = np.expand_dims(X_train, -1)
print(X_train.shape)
# Out:
# (15, 1)

# %% [markdown]
# ### Implement the ` LinearRegression` class
# Make sure it works with more than 1 feature.
# **NOTE:** Do **NOT** forget to include a bias term in the weights.

# %%
from sklearn.metrics import mean_squared_error as mse
class LinearRegression:
    def __init__(self, lr=0.001, epochs=30):
        """
        Fits a linear regression model on a given dataset.

        Args:
            lr: learning rate
            epochs: number of iterations over the dataset
        """
        self.lr = lr
        self.epochs = epochs
        ######################
        #   YOUR CODE HERE   #
        ######################
        # You may add additional fields

    def train(self, X, y):
        """
        Initialize weights. Iterate through the dataset and update weights once every epoch.

        Args:
            X: features
            y: target
        """
        ######################
        #   YOUR CODE HERE   #
        ######################
        self.num_features = X.shape[-1]
        self.n = X.shape[0]

        self.w = np.random.rand(self.num_features)
        self.b = np.random.rand(1)
        print("weight shape : ", self.w.shape)
        print("bias shape :", self.b.shape)

        for epoch in range(self.epochs):
            #print("epoch :", epoch)
            loss = 0

            yhat = X.dot(self.w) + self.b
            #print(yhat)
            #print(y)
            dw = -2*X.T.dot(y-yhat)/self.n
            db = -2*np.sum(y-yhat)/self.n

            self.w = self.w - self.lr*dw
            self.b = self.b - self.lr*db
            loss += mse(yhat, y)


    def update_weights(self, X, y):
        """
        Helper function to calculate the gradients and update weights using batch gradient descent.

        Args:
            X: features
            y: target
        """
        ######################
        #   YOUR CODE HERE   #
        ######################



    def predict(self, X):
        """
        Predict values using the weights.

        Args:
            X: features

        Returns:
            The predicted value.
        """
        ######################
        #   YOUR CODE HERE   #
        ######################
        output = X.dot(self.w) + self.b
        return output

# %% [markdown]
# ### Build the model and train on the dataset.

# %%
model = LinearRegression(0.01, 100000)
model.train(X_train, y_train)
# Out:
# weight shape :  (1,)
# bias shape : (1,)

# %% [markdown]
# ### (5 points) Implement the evaluation metric `mean squared error`.
# We use the [mean squared error (MSE)](https://en.wikipedia.org/wiki/Mean_squared_error) as the metric to evaluate our model.

# %%
def mean_squared_error(y_pred, y_actual):
    """
    Calculates the mean squared error between two vectors.

    Args:
        y_pred: predicted values
        y_actual: actual/true values

    Returns:
        The mean squared error.
    """
    ######################
    #   YOUR CODE HERE   #
    ######################
    return mse(y_pred, y_actual)

# %% [markdown]
# ### Make predictions using the model and evaluate it.

# %%
y_pred = model.predict(X_train)
print("Train MSE: {:.4f}".format(mean_squared_error(y_pred, y_train)))
# Out:
# Train MSE: 0.4994

# %% [markdown]
# ### Plot the predicted and the actual values.

# %%
import matplotlib.pyplot as plt

plt.scatter(X_train, y_train, marker='X', label='actual')
plt.scatter(X_train, y_pred, marker='o', label='predicted')
plt.legend()
plt.show()
